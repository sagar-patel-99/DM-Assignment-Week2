# %%
pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.4/484.4 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 63.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 68.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.0 MB/s eta 0:00:00
# ...

# %%
#connect to google drive
from google.colab import drive
drive.mount("/content/gdrive")
sys_path=("/content/gdrive/MyDrive/Colab Notebooks/Indian_movies.csv")
# Out:
# Mounted at /content/gdrive

# %%
#call dataset from drive
import pandas as pd
df =pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/Indian_movies.csv")
df.head()
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0  Rank                          Movie Names  \
# 0             0     1  Ramayana: The Legend of Prince Rama
# 1             1     2           Rocketry: The Nambi Effect
# 2             2     3                              Nayakan
# 3             3     4                             Gol Maal
# 4             4     5                           Anbe Sivam
# ..          ...   ...                                  ...
# 245         245   246                           Kai Po Che
# 246         246   247                       Poove Unakkaga
# 247         247   248                                Raazi
# 248         248   249                          Dasvidaniya
# 249         249   250                                  Dia
#
#                                                  Links  Rating  Year  \
# 0    https://www.imdb.com//title/tt0259534/?ref_=fe...     9.2  1993
# 1    https://www.imdb.com//title/tt9263550/?ref_=fe...     8.7  2022
# ...

# %%
# import pycaret clustering and init setup
from pycaret.clustering import *
s = setup(df)
# Out:
# <style type="text/css">
# #T_2cb4f_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2cb4f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cb4f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2cb4f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cb4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2cb4f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2cb4f_row0_col1" class="data row0 col1" >4083</td>
#     </tr>
#     <tr>
#       <th id="T_2cb4f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2cb4f_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_2cb4f_row1_col1" class="data row1 col1" >(250, 9)</td>
#     </tr>
#     <tr>
# ...

# %%
# import ClusteringExperiment and init the class
from pycaret.clustering import ClusteringExperiment
exp = ClusteringExperiment()

# %%
# check the type of exp
type(exp)
# Out:
# pycaret.clustering.oop.ClusteringExperiment

# %%
# train kmeans model
kmeans = create_model('kmeans')
# Out:
# <style type="text/css">
# </style>
# <table id="T_725d9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_725d9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_725d9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_725d9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_725d9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_725d9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_725d9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_725d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_725d9_row0_col0" class="data row0 col0" >0.5047</td>
#       <td id="T_725d9_row0_col1" class="data row0 col1" >924.7808</td>
# ...

# %%
kmeans_cluster = assign_model(kmeans)
kmeans_cluster
# Out:
#      Unnamed: 0  Rank                          Movie Names  \
# 0             0     1  Ramayana: The Legend of Prince Rama
# 1             1     2           Rocketry: The Nambi Effect
# 2             2     3                              Nayakan
# 3             3     4                             Gol Maal
# 4             4     5                           Anbe Sivam
# ..          ...   ...                                  ...
# 245         245   246                           Kai Po Che
# 246         246   247                       Poove Unakkaga
# 247         247   248                                Raazi
# 248         248   249                          Dasvidaniya
# 249         249   250                                  Dia
#
#                                                  Links  Rating  Year  \
# 0    https://www.imdb.com//title/tt0259534/?ref_=fe...     9.2  1993
# 1    https://www.imdb.com//title/tt9263550/?ref_=fe...     8.7  2022
# ...

# %%
# plot pca cluster plot
plot_model(kmeans, plot = 'cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# plot elbow
plot_model(kmeans, plot = 'elbow')

# %%
# plot silhouette
plot_model(kmeans, plot = 'silhouette')

# %%
# to control the scale of plot
plot_model(kmeans, plot = 'elbow', scale = 2)

# %%
# save model
save_model(kmeans, 'my_first_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Unnamed: 0', 'Rank', 'Rating',
#                                               'Year'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Movie Names', 'Links',
#                                               'Duration_of_movie', 'Genere',
#                                               'Description'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['Movie Names', 'Links',
#                                               'Duration_of_movie', 'Genere',
#                                               'Description'],
# ...
